# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import scipy as sp
import requests
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
df_weather = pd.read_csv("external_data.csv")

# %%
df_weather2 = pd.read_csv("external_data8.csv")

# %%
df_weather
# Out:
#        Unnamed: 0              date  Temperature (C) wind_dir  wind_speed  \
# 0               0  01-09-2020 23:00             14.9      NNE         5.6
# 1               1  01-09-2020 22:00             15.2      NNE         5.6
# 2               2  01-09-2020 21:00             16.4       NE         7.4
# 3               3  01-09-2020 20:00             17.1      NNE         7.4
# 4               4  01-09-2020 19:00             18.5      NNE         5.6
# ...           ...               ...              ...      ...         ...
# 11549       11552  31-12-2021 04:00              9.0        S         5.6
# 11550       11553  31-12-2021 03:00              9.5        S        11.1
# 11551       11554  31-12-2021 02:00              9.6       SO         5.6
# 11552       11555  31-12-2021 01:00             10.3        S         7.4
# 11553       11556  31-12-2021 00:00             10.8        S        11.1
#
#        Humidity  Visibility  Precipitation  pressure1  sunshine_time  suntime  \
# ...

# %%
df_weather2
# Out:
#        Unnamed: 0                 date  Temperature (C) wind_dir  wind_speed  \
# 0               0  2020-09-01 23:00:00             14.9      NNE         5.6
# 1               1  2020-09-01 22:00:00             15.2      NNE         5.6
# 2               2  2020-09-01 21:00:00             16.4       NE         7.4
# 3               3  2020-09-01 20:00:00             17.1      NNE         7.4
# 4               4  2020-09-01 19:00:00             18.5      NNE         5.6
# ...           ...                  ...              ...      ...         ...
# 11552       11552  2021-12-31 04:00:00              9.0        S         5.6
# 11553       11553  2021-12-31 03:00:00              9.5        S        11.1
# 11554       11554  2021-12-31 02:00:00              9.6       SO         5.6
# 11555       11555  2021-12-31 01:00:00             10.3        S         7.4
# 11556       11556  2021-12-31 00:00:00             10.8        S        11.1
#
# ...

# %%
df_weather2.columns[df_weather.columns != df_weather2.columns]
# Out:
# Index(['date_only', 'new_cases'], dtype='object')

# %%
df_weather2.new_cases
# Out:
# 0          5104.0
# 1          5104.0
# 2          5104.0
# 3          5104.0
# 4          5104.0
#            ...
# 11552    232200.0
# 11553    232200.0
# 11554    232200.0
# 11555    232200.0
# 11556    232200.0
# Name: new_cases, Length: 11557, dtype: float64

# %%
df_weather.new_cases
# Out:
# 0          5104.0
# 1          5104.0
# 2          5104.0
# 3          5104.0
# 4          5104.0
#            ...
# 11549    232200.0
# 11550    232200.0
# 11551    232200.0
# 11552    232200.0
# 11553    232200.0
# Name: new_cases, Length: 11554, dtype: float64

# %% [markdown]
# ## _Model6_

# %%
    params = {'learning_rate': 0.15, 'max_depth': 10, 'l2_leaf_reg': 10,
              'iterations': 900, 'max_bin': 280, 'bagging_temperature': 1, 'random_strength': 10, 'task_type': 'GPU'}

# %% [markdown]
# Mean CV scores
# ----------------------------
#         score             rmse          time
#         train  0.313 +- 0.0304  12.7 +- 2.07
#         valid   0.698 +- 0.092   2.5 +- 0.09
#         test   0.681 +- 0.0758   0.9 +- 0.01
# ----------------------------
# Bagged scores
# ----------------------------
#         score   rmse
#         valid  0.704
#         test   0.566

# %% [markdown]
# ## _Model7_

# %%
params = {'learning_rate': 0.15, 'max_depth': 11, 'l2_leaf_reg': 10,
              'iterations': 900, 'max_bin': 280, 'bagging_temperature': 1, 'random_strength': 10, 'task_type': 'GPU'}

# %% [markdown]
# Mean CV scores
# ----------------------------
#         score             rmse          time
#         train  0.299 +- 0.0309  16.7 +- 2.32
#         valid   0.702 +- 0.086   2.6 +- 0.03
#         test   0.673 +- 0.0771   0.9 +- 0.02
# ----------------------------
# Bagged scores
# ----------------------------
#         score   rmse
#         valid  0.708
#         test   0.561
